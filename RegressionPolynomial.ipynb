# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
# 1.Data generation
np.random.seed(42)
X = np.linspace(-3, 3, 100)
# Actual function: y = xˆ2
y = X**2 + np.random.normal(0, 1.5, 100) # Adding noise
# X

# %%
# X.shape

# %%
# y

# %%
# y.shape

# %%
# reshape for sklearn
X = X.reshape(-1, 1)
# X.shape

# %%
y = y.reshape(-1, 1)
# y.shape

# %%
# 2. split data(70% Train, 30% Test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# 3. train linear regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Extracting model parameters
intercept = model.intercept_[0]
#print(intercept)
slope = model.coef_[0][0]
#print(slope)
Line_equation = f'y = {slope:.2f}x + {intercept:.2f}'
#print(Line_equation)

# %%
# predictions
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
# Calculate Metrics
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
#print(rmse_train)
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
#print(rmse_test)
r2_train = r2_score(y_train, y_train_pred)
#print(r2_train)
r2_test = r2_score(y_test, y_test_pred)
#print(r2_test)

# %%
# plotting
# Plot 1:Only Data Distribution
plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, color='blue', label='Train Data (70%)', alpha=0.7)
plt.scatter(X_test, y_test, color='green', marker='^', label='Test Data (30%)', alpha=0.7)
plt.title('1. Data Distribution (Train vs Test)')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# 2. Plot Linear Resgression Fit With Equation
plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, color='blue', label='Train Data')
plt.scatter(X_test, y_test, color='green', marker='^', label='Test Data')

plt.plot(X, model.predict(X), color='red', linewidth=3, label=f'Model:{Line_equation}')

# Added the equation to the title
plt.title(f'2. Liner Regression Fit (underfitting)\nTest RMSE:{rmse_test:.2f} |Test R2: {r2_test:.2f}\n Equation: {Line_equation}')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# 3 Plot. Residuals (Errors) Visualization
plt.figure(figsize=(10, 6))
plt.scatter(X_test, y_test, color='green', marker='^', label='Test Data', s=50)
plt.plot(X_test, y_test_pred, color='red', label='Predicted Points', marker='x')
plt.vlines(X_test, y_test, y_test_pred, color='gray', linestyle='--', label='Error (Residuals)')
plt.plot(X, model.predict(X), color='red')

plt.title('3. Visualization of Error (Residuals) on Test Data')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Printing Metrics and Equation
print('-'* 30)
print(f'Model Equation: {Line_equation}')
print('-'* 30)
print(f'Train Rmse: {rmse_train}')
print(f'Test Rmse: {rmse_test}')
print('-'* 30)
print(f'Train R2 score: {r2_train}')
print(f'Test R2 score: {r2_test}')
print('-'* 30)
print(f'intercept (Bias): {intercept}')
print(f'coefficient (Weight):{slope}')
print('-'* 30)
# Out:
# ------------------------------
# Model Equation: y = 0.12x + 2.88
# ------------------------------
# Train Rmse: 3.2519162937542885
# Test Rmse: 2.8300138656603573
# ------------------------------
# Train R2 score: 0.00409556762105745
# Test R2 score: -0.02115610726973638
# ------------------------------
# intercept (Bias): 2.8806367265452724
# coefficient (Weight):0.11891539062525486
# ------------------------------

# %%
# Polynominial
# new add to older than 
from sklearn.preprocessing import PolynomialFeatures

# %%
# 1 Data Genaration
np.random.seed(42)
X = np.linspace(-3, 3, 100).reshape(-1, 1)
# Actual function: y = xˆ2
y = X**2 + np.random.normal(0, 1.5, 100).reshape(-1, 1)# Adding noise

# %%
# 2. Split Data(70% Train , 30% Test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# 3. Feature Transformation (Degree 2)
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
# 4. Train model
model = LinearRegression()
model.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
# Extracing Polynomial Equation
# model.coen_[0] contains [w_0, w_1, w_2] correspinding to [1, x, xˆ2]
weights = model.coef_[0]
#print(weights)
bias = model.intercept_[0]
#print(bias)
poly_equation = f'y = {weights[2]:.2f}xˆ2 + {weights[1]:.2f}x + {bias:.2f}'
#print(poly_equation)
# Constructing the equation string:y = w2*xˆ2 + w1*x + b
# Note: weights[0] is usually 0 because 'bias' is handeld by model.intercept_

# %%
# predictions
y_train_pred = model.predict(X_train_poly)
y_test_pred = model.predict(X_test_poly)

# %%
# Calculate Metrics
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
#print(rmse_train)
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
#print(rmse_test)
r2_train = r2_score(y_train, y_train_pred)
#print(r2_train)
r2_test = r2_score(y_test, y_test_pred)
#print(r2_test)

# %%
# Generating a smooth curve for plotting the model
X_seq = np.linspace(X.min(), X.max(), 300).reshape(-1, 1)
X_seq_poly = poly.transform(X_seq)
y_seq_pred = model.predict(X_seq_poly)

# %%
# --- Plotting ---
# Plot 1:Only Data Distribution
plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, color='blue', label='Train Data')
plt.scatter(X_test, y_test, color='green', marker='^', label='Test Data')
plt.title('Data Distribution')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Plot 2: Polynomial Regression Fit(Degree2) With Equation
plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, color='blue', label='Train Data', alpha=0.5)
plt.scatter(X_test, y_test, color='green', marker='^', label='Test Data', alpha=0.5)

# plotting the curve
plt.plot(X_seq, y_seq_pred, color='red', linewidth=3, label=f'Model: {poly_equation}')

plt.title(f'Ploynomial Fit (Optimal)\nRMSE: {rmse_test:.2f} | R2: {r2_test:.2f}\n{poly_equation}')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Plot 3: Residuals (Error) Visualization
plt.figure(figsize=(10, 6))
plt.scatter(X_test, y_test, color='green', marker='^', label='Actual Test Data', s=50)
plt.plot(X_test, y_test_pred, color='black', label='Predicted Points', marker='x', linestyle='None', ms=6)
plt.vlines(X_test, y_test, y_test_pred, color='gray', linestyle='--', alpha=0.5, label='Error (Residuals)')
plt.plot(X_seq, y_seq_pred, color='red', alpha=0.2)

plt.title('Visualization of Error (Residuals) on Test Data')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
# Printing Metrics & Equation
print("-" * 30)
print(f'Learned Equation: {poly_equation}')
print("-" * 30)
print(f'Intercept (b): {bias:.4f}')
print(f'Coefficients (Weights): {weights}')
print("-" * 30)
print(f'Train Rmse: {rmse_train:.4f}')
print(f'Test Rmse: {rmse_test:.4f}')
print("-" * 30)
print(f'Train R2 Score: {r2_train:.4f}')
print(f'Test R2 Score: {r2_test:.4f}')
print("-" * 30)
# Out:
# ------------------------------
# Learned Equation: y = 1.04xˆ2 + 0.03x + -0.31
# ------------------------------
# Intercept (b): -0.3104
# Coefficients (Weights): [0.         0.02910938 1.03795165]
# ------------------------------
# Train Rmse: 1.4405
# Test Rmse: 1.1196
# ------------------------------
# Train R2 Score: 0.8046
# Test R2 Score: 0.8402
# ------------------------------

# %%
# Data Generation
np.random.seed(42)
X = np.linspace(-3, 3, 100).reshape(-1, 1)
y = X**2 + np.random.normal(0, 1.5, 100).reshape(-1, 1)

# Splitting Data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# List to store metrics
degrees = range(1, 26)
train_rmse_list = []
test_rmse_list = []
train_r2_list = []
test_r2_list = []

for degree in degrees:
    # Feature Transformation
    poly_features = PolynomialFeatures(degree=degree)
    X_train_poly = poly_features.fit_transform(X_train)
    X_test_poly = poly_features.transform(X_test)

    # Model Training
    model = LinearRegression()
    model.fit(X_train_poly, y_train)

    # Prediction
    y_train_pred = model.predict(X_train_poly)
    y_test_pred = model.predict(X_test_poly)

    # Calculate Rmse
    train_rmse_list.append(np.sqrt(mean_squared_error(y_train, y_train_pred)))
    test_rmse_list.append(np.sqrt(mean_squared_error(y_test, y_test_pred)))

    # Calculate R2
    train_r2_list.append(r2_score(y_train, y_train_pred))
    test_r2_list.append(r2_score(y_test, y_test_pred))
    
# Plotting
plt.figure(figsize=(18, 6))

# Plot 1:Rmse
plt.subplot(1, 2, 1)
plt.plot(degrees, train_rmse_list, label='Train Rmse', marker='o', color='blue') 
plt.plot(degrees, test_rmse_list, label='Test Rmse', marker='o', color='red')
plt.xlabel('Polynomial Degree')
plt.ylabel('Rmse')
plt.title('Rmse vs Polynomial Degree')
plt.xticks(degrees)
plt.grid(True, alpha=0.3)
plt.legend()

# Plot 2:R2 score
plt.subplot(1, 2, 2)
plt.plot(degrees, train_r2_list, label='Train R2', marker='o', color='blue')
plt.plot(degress, test_r2_list, label='Test R2', marker='o', color='green')
plt.xlabel('Ploynomial Degree')
plt.ylabel('R2 Score')
plt.title('R2 Score vs ploynomial Degree')
plt.xticks(degrees)
plt.grid(True, alpha=0.3)
plt.ylim(-2, 1.1) #Limining y-axis to focus on the relevant range
plt.legend()

plt.tight_layout()
plt.show()
